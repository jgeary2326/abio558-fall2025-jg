# %% [markdown]
# # 2.8- Sequencing data and time series analysis
#
# ### Learning goals for today
# 1. Load, visualize and understand RNA sequencing data
# 2. Annotating scRNAseq data using marker genes
# 3. Bonus: Analyzing time series data
#
# ---
# ### How to use this notebook during class
# - Follow along as we go
# - Use your **Cards** to indicate where you're at:
#     - A **🟩Green card** means you are caught up with Max and **ready to help your classmates**
#     - A **🟥Red card** means you are stuck and need help
# - <span style='color:red;'>EXERCISE</span> — work on this problem by yourself, or try with a partner if you get stuck
# ---

# %% [markdown]
# First let's import some libraries we will use today. Remember if you don't have a library installed you can pip install it with:
#
# %pip install *package_name*

# %% [markdown]
# ## 1) scRNAseq data - looking at it
#
# Download `tags.csv` and `ct.csv` from brightspace or the course github
#
# Data originally from: https://www.pnas.org/doi/full/10.1073/pnas.1507125112

# %%
# %pip install scanpy
# %pip install igraph
# Out:
# Collecting scanpy
#   Downloading scanpy-1.11.5-py3-none-any.whl.metadata (9.3 kB)
# Collecting anndata>=0.8 (from scanpy)
#   Downloading anndata-0.12.4-py3-none-any.whl.metadata (9.9 kB)
# Collecting h5py>=3.7.0 (from scanpy)
#   Downloading h5py-3.15.1-cp313-cp313-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: joblib in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from scanpy) (1.5.2)
# Collecting legacy-api-wrap>=1.4.1 (from scanpy)
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: matplotlib>=3.7.5 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from scanpy) (3.10.7)
# Collecting natsort (from scanpy)
#   Downloading natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting networkx>=2.7.1 (from scanpy)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting numba!=0.62.0rc1,>=0.57.1 (from scanpy)
#   Downloading numba-0.62.1-cp313-cp313-win_amd64.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from scanpy) (2.3.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from scanpy) (25.0)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from scanpy) (2.3.3)
# Collecting patsy!=1.0.0 (from scanpy)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting pynndescent>=0.5.13 (from scanpy)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: scikit-learn>=1.1.3 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from scanpy) (1.7.2)
# Requirement already satisfied: scipy>=1.8.1 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from scanpy) (1.16.2)
# Requirement already satisfied: seaborn>=0.13.2 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from scanpy) (0.13.2)
# Collecting session-info2 (from scanpy)
#   Downloading session_info2-0.2.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting statsmodels>=0.14.5 (from scanpy)
#   Downloading statsmodels-0.14.5-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting tqdm (from scanpy)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting umap-learn>=0.5.6 (from scanpy)
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl.metadata (25 kB)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.8->scanpy)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.8->scanpy)
#   Downloading zarr-3.1.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from matplotlib>=3.7.5->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from matplotlib>=3.7.5->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from matplotlib>=3.7.5->scanpy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from matplotlib>=3.7.5->scanpy) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from matplotlib>=3.7.5->scanpy) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from matplotlib>=3.7.5->scanpy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from matplotlib>=3.7.5->scanpy) (2.9.0.post0)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba!=0.62.0rc1,>=0.57.1->scanpy)
#   Downloading llvmlite-0.45.1-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from pandas>=1.5.3->scanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from pandas>=1.5.3->scanpy) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7.5->scanpy) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from scikit-learn>=1.1.3->scanpy) (3.6.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading numcodecs-0.16.3-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: typing-extensions>=4.9 in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (4.15.0)
# Requirement already satisfied: pyyaml in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (6.0.2)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading crc32c-2.8-cp313-cp313-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: colorama in c:\users\jjag1\anaconda3\envs\abio558\lib\site-packages (from tqdm->scanpy) (0.4.6)
# Downloading scanpy-1.11.5-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 15.0 MB/s  0:00:00
# Downloading anndata-0.12.4-py3-none-any.whl (170 kB)
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
# Downloading h5py-3.15.1-cp313-cp313-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 18.1 MB/s  0:00:00
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 17.0 MB/s  0:00:00
# Downloading numba-0.62.1-cp313-cp313-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    -------------------------------------- - 2.6/2.7 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 11.3 MB/s  0:00:00
# Downloading llvmlite-0.45.1-cp313-cp313-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    - -------------------------------------- 1.8/38.1 MB 9.6 MB/s eta 0:00:04
#    --- ------------------------------------ 3.4/38.1 MB 8.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.0/38.1 MB 8.6 MB/s eta 0:00:04
#    ------- -------------------------------- 6.8/38.1 MB 7.9 MB/s eta 0:00:04
#    --------- ------------------------------ 8.7/38.1 MB 8.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 10.7/38.1 MB 8.3 MB/s eta 0:00:04
#    ------------ --------------------------- 12.3/38.1 MB 8.2 MB/s eta 0:00:04
#    --------------- ------------------------ 14.4/38.1 MB 8.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 17.0/38.1 MB 8.8 MB/s eta 0:00:03
#    -------------------- ------------------- 19.7/38.1 MB 9.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.3/38.1 MB 9.4 MB/s eta 0:00:02
#    -------------------------- ------------- 25.4/38.1 MB 9.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.3/38.1 MB 10.1 MB/s eta 0:00:01
#    -------------------------------- ------- 30.7/38.1 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.0/38.1 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------- -- 35.7/38.1 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  37.7/38.1 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 10.1 MB/s  0:00:03
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Downloading statsmodels-0.14.5-cp313-cp313-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------- ----------------------------- 2.6/9.6 MB 13.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.6 MB 13.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.6 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 12.0 MB/s  0:00:00
# Downloading umap_learn-0.5.9.post2-py3-none-any.whl (90 kB)
# Downloading zarr-3.1.3-py3-none-any.whl (276 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.3-cp313-cp313-win_amd64.whl (803 kB)
#    ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#    ---------------------------------------- 803.2/803.2 kB 9.8 MB/s  0:00:00
# Downloading crc32c-2.8-cp313-cp313-win_amd64.whl (66 kB)
# Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Downloading session_info2-0.2.3-py3-none-any.whl (16 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, session-info2, patsy, numcodecs, networkx, natsort, llvmlite, legacy-api-wrap, h5py, donfig, crc32c, array-api-compat, numba, zarr, statsmodels, pynndescent, umap-learn, anndata, scanpy
#
#    ----------------------------------------  0/19 [tqdm]
#    ----------------------------------------  0/19 [tqdm]
#    ---- -----------------------------------  2/19 [patsy]
#    ---- -----------------------------------  2/19 [patsy]
#    ---- -----------------------------------  2/19 [patsy]
#    ---- -----------------------------------  2/19 [patsy]
#    ------ ---------------------------------  3/19 [numcodecs]
#    ------ ---------------------------------  3/19 [numcodecs]
#    ------ ---------------------------------  3/19 [numcodecs]
#    ------ ---------------------------------  3/19 [numcodecs]
#    ------ ---------------------------------  3/19 [numcodecs]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    -------- -------------------------------  4/19 [networkx]
#    ---------- -----------------------------  5/19 [natsort]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    ------------ ---------------------------  6/19 [llvmlite]
#    -------------- -------------------------  7/19 [legacy-api-wrap]
#    ---------------- -----------------------  8/19 [h5py]
#    ---------------- -----------------------  8/19 [h5py]
#    ---------------- -----------------------  8/19 [h5py]
#    ---------------- -----------------------  8/19 [h5py]
#    ---------------- -----------------------  8/19 [h5py]
#    ---------------- -----------------------  8/19 [h5py]
#    ------------------ ---------------------  9/19 [donfig]
#    ----------------------- ---------------- 11/19 [array-api-compat]
#    ----------------------- ---------------- 11/19 [array-api-compat]
#    ----------------------- ---------------- 11/19 [array-api-compat]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    ------------------------- -------------- 12/19 [numba]
#    --------------------------- ------------ 13/19 [zarr]
#    --------------------------- ------------ 13/19 [zarr]
#    --------------------------- ------------ 13/19 [zarr]
#    --------------------------- ------------ 13/19 [zarr]
#    --------------------------- ------------ 13/19 [zarr]
#    --------------------------- ------------ 13/19 [zarr]
#    --------------------------- ------------ 13/19 [zarr]
#    --------------------------- ------------ 13/19 [zarr]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ----------------------------- ---------- 14/19 [statsmodels]
#    ------------------------------- -------- 15/19 [pynndescent]
#    ------------------------------- -------- 15/19 [pynndescent]
#    --------------------------------- ------ 16/19 [umap-learn]
#    --------------------------------- ------ 16/19 [umap-learn]
#    ----------------------------------- ---- 17/19 [anndata]
#    ----------------------------------- ---- 17/19 [anndata]
#    ----------------------------------- ---- 17/19 [anndata]
#    ----------------------------------- ---- 17/19 [anndata]
#    ------------------------------------- -- 18/19 [scanpy]
#    ------------------------------------- -- 18/19 [scanpy]
#    ------------------------------------- -- 18/19 [scanpy]
#    ------------------------------------- -- 18/19 [scanpy]
#    ------------------------------------- -- 18/19 [scanpy]
#    ------------------------------------- -- 18/19 [scanpy]
#    ------------------------------------- -- 18/19 [scanpy]
#    ------------------------------------- -- 18/19 [scanpy]
#    ------------------------------------- -- 18/19 [scanpy]
#    ---------------------------------------- 19/19 [scanpy]
#
# Successfully installed anndata-0.12.4 array-api-compat-1.12.0 crc32c-2.8 donfig-0.8.1.post1 h5py-3.15.1 legacy-api-wrap-1.4.1 llvmlite-0.45.1 natsort-8.4.0 networkx-3.5 numba-0.62.1 numcodecs-0.16.3 patsy-1.0.2 pynndescent-0.5.13 scanpy-1.11.5 session-info2-0.2.3 statsmodels-0.14.5 tqdm-4.67.1 umap-learn-0.5.9.post2 zarr-3.1.3
# Note: you may need to restart the kernel to use updated packages.
# Collecting igraph
#   Downloading igraph-1.0.0-cp39-abi3-win_amd64.whl.metadata (4.5 kB)
# Collecting texttable>=1.6.2 (from igraph)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Downloading igraph-1.0.0-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 3.2/3.2 MB 15.8 MB/s  0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph
#
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    ---------------------------------------- 2/2 [igraph]
#
# Successfully installed igraph-1.0.0 texttable-1.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import anndata
import seaborn as sns
import scanpy 
import numpy as np

# %% [markdown]
# Generally it is best to not keep data in your code repository, and GitHub cannot sync large files. So let's point our code to the file path on the computer

# %%
data_directory = '/Users/jjag1/Downloads'
filepath_tags = os.path.join(data_directory, 'tags.csv')
filepath_celltypes = os.path.join(data_directory, 'ct.csv')

os.path.exists(filepath_celltypes)
# Out:
# True

# %% [markdown]
# First we'll use pandas to load the data. There are two things we'll load:
# 1. The gene counts matrix, which has cells along the rows and genes along the columns
# 2. The cell type array, which has labels for each annotated cell type

# %%
reads_df = pd.read_csv(filepath_tags, index_col=0).T
reads_df.head()
# Out:
#             1/2-SBSRNA4  A1BG  A1BG-AS1  A1CF  A2LD1  A2M  A2ML1  A2MP1  \
# GSM1658365            0     0         0     0      0    0      0      0
# GSM1658366            0     0         0     0      0    0      0      0
# GSM1658364            0     0         0     0      0    0      0      0
# GSM1658363            0     0         0     0      0    0      0      0
# GSM1658362            0     0         0     0      0    0      0      0
#
#             A4GALT  A4GNT  ...  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B  ZYX  \
# GSM1658365       0      0  ...      0    28     0     5       0      67    9
# GSM1658366       0      0  ...      0     0     0    22       0       0    6
# GSM1658364       0      0  ...      0     0     0     0       0       0    0
# GSM1658363       0      0  ...      0     0     0    18       0       0    0
# GSM1658362       0      0  ...      0     0     0     8       0       0    0
#
#             ZZEF1  ZZZ3  tAKR
# GSM1658365      0     0     0
# GSM1658366      0     7     0
# GSM1658364      0     0     0
# GSM1658363      0     4     0
# GSM1658362      0     0     0
#
# [5 rows x 22085 columns]

# %% [markdown]
# These data have already been annotated. Let's look at the cell types in the annotation

# %%
cell_types = pd.read_csv(filepath_celltypes, index_col=0)
cell_types.value_counts()
# Out:
# cell_type
# neurons              131
# fetal_quiescent      110
# astrocytes            62
# oligodendrocytes      38
# fetal_replicating     25
# endothelial           20
# OPC                   18
# microglia             16
# Name: count, dtype: int64

# %% [markdown]
# This is a big matrix, and scanpy uses a special data type to hold this and run calcuations on it called an Annotated Data (AnnData) object
#
# Let's make an AnnData (Annotated Data) object from our two dataframes

# %%
adata=anndata.AnnData(reads_df, obs=cell_types)
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 420 × 22085
#     obs: 'cell_type'

# %% [markdown]
# Let's do some standard preprocessing steps to remove cells that don't have many genes, and genes that don't show up in many cells

# %%
scanpy.pp.filter_cells(adata, min_genes=100)
scanpy.pp.filter_genes(adata, min_cells=3)
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 420 × 19231
#     obs: 'cell_type', 'n_genes'
#     var: 'n_cells'

# %% [markdown]
# Notice that when we do stuff to adata, it modifies the object **in place** and adds new observations to the table
#
# The next step is to normalize the read counts within a cell to that cell's median reads. That lets us compare amount of gene expression across cells that maybe just have more mRNA around for whatever reason.
#
# Then we'll transform to log(count+1). Log transforming helps make the variances more comparable for genes that may differ in abundance over orders of magnitude.

# %%
#median count depth normalization
scanpy.pp.normalize_total(adata)

scanpy.pp.log1p(adata)
adata
# Out:
# AnnData object with n_obs × n_vars = 420 × 19231
#     obs: 'cell_type', 'n_genes'
#     var: 'n_cells'
#     uns: 'log1p'

# %% [markdown]
# **Feature selection:** Let's add tags to indicate "highly variable genes," to help us focus on genes that are differentially expressed across the cells. We will use this for visualizing lower dimensional representations (like UMAP) and for clustering

# %%
scanpy.pp.highly_variable_genes(adata,n_top_genes=2000)
adata
# Out:
# AnnData object with n_obs × n_vars = 420 × 19231
#     obs: 'cell_type', 'n_genes'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'

# %% [markdown]
# Let's do PCA to get a sense of the dimensionality of the data

# %%
scanpy.tl.pca(adata)
scanpy.pl.pca_variance_ratio(adata, n_pcs=10, log=True)

# %% [markdown]
# Let's look at a lower dimensional representation of the gene expression profiles of these cells using UMAP. We will use pre-annotated cell types to color the points

# %%
#compute neighborhood graph (-distance matrix
scanpy.pp.neighbors(adata)

#prject data into UMAP coordinates
scanpy.tl.umap(adata)

#display UMAP
scanpy.pl.umap(adata, color='cell_type', size=100, alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 8
#       5 scanpy.tl.umap(adata)
#       7 #display UMAP
# ----> 8 scanpy.pl.umap(adata, color='cell_type', size=100, alpha=0.5, arrows=True)
#
# File ~\anaconda3\envs\ABIO558\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:686, in umap(adata, **kwargs)
#     627 @_wraps_plot_scatter
#     628 @_doc_params(
#     629     adata_color_etc=doc_adata_color_etc,
#    (...)    633 )
#     634 def umap(adata: AnnData, **kwargs) -> Figure | Axes | list[Axes] | None:
#     635     """Scatter plot in UMAP basis.
#     636
#     637     Parameters
#    (...)    684
#     685     """
# --> 686     return embedding(adata, "umap", **kwargs)
#
# File ~\anaconda3\envs\ABIO558\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:438, in embedding(adata, basis, color, mask_obs, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, marker, **kwargs)
#     434     _utils.plot_edges(
#     435         ax, adata, basis, edges_width, edges_color, neighbors_key=neighbors_key
#     436     )
#     437 if arrows:
# --> 438     _utils.plot_arrows(ax, adata, basis, arrows_kwds)
#     440 if value_to_plot is None:
#     441     # if only dots were plotted without an associated value
#     442     # there is not need to plot a legend or a colorbar
#     443     continue
#
# File ~\anaconda3\envs\ABIO558\Lib\site-packages\scanpy\plotting\_utils.py:567, in plot_arrows(axs, adata, basis, arrows_kwds)
#     561 if v_prefix is None:
#     562     msg = (
#     563         "`arrows=True` requires "
#     564         f"`'velocity_{basis}'` from scvelo or "
#     565         f"`'Delta_{basis}'` from velocyto."
#     566     )
# --> 567     raise ValueError(msg)
#     568 if v_prefix == "velocity":
#     569     logg.warning(
#     570         "The module `scvelo` has improved plotting facilities. "
#     571         "Prefer using `scv.pl.velocity_embedding` to `arrows=True`."
#     572     )
#
# ValueError: `arrows=True` requires `'velocity_umap'` from scvelo or `'Delta_umap'` from velocyto.

# %% [markdown]
# ## 2) scRNAseq data - clustering and annotating
# What if we didn't have cell type annotations? Let's see how we could make our own using clustering and known marker genes

# %% [markdown]
# Now let's cluster our cells using the Leiden method. We can control how fine-scale the clustering is with the `resolution` parameter.

# %%
scanpy.tl.leiden(adata, flavor='igraph', resolution=1.2)
scanpy.pl.umap(adata, color='leiden')

# %% [markdown]
# ### <span style='color:red;'>EXERCISE 1</span>: Find a good resolution value  (5 min)
#
# Play with the `resolution` parameter to find a good value that gives use approximately the right number of clusters. You can iterate on this while trying to assign clusters to cell types

# %% [markdown]
# Suppose we have marker genes for each of the cell types we are interested in. We can tell scanpy about these marker genes using a dictionary like this one:

# %%
marker_genes_dict = {
    "OPC": ["PCDH15", "MEGF11", "LHFPL3", "PDGFRA"],
    "Astrocytes": ["SLC14A1", "GLIS3", "GLI3", "CTH", "HGF"],
    "Endothelial": ["APOLD1", "FLT1", "A2M", "TM4SF1"],
    "microglia": ["CCL4", "GPR183", "CD83", "CD14", "CSF1R"],
    "neurons": ["KCNK1", "NELL1", "COBL", "DCN", "DLX2", "DLX5", "SST", "PNOC"],
    "oligodendrocytes": ["DAAM2", "ASPA", "MAL", "MAG", "GSN"],
}

# %% [markdown]
# Now let's see how our clusters line up to real cell types using a dotplot

# %%
scanpy.pl.dotplot(adata, marker_genes_dict, groupby='leiden')

# %%
cluster_mapping_dictionary =     {
                                  "0": "?",
                                  "1": "Endothelial",
                                  "2": "Astrocytes",
                                  "3": "Neurons",
                                  "4": "Oligodendrocytes",
                                  "5": "OPC",
                                 }

# %% [markdown]
# Let's add an observation to the andata object to hold our putative cell types. We'll do this using the pandas .map() function on our dictionary
#
# Then we'll look at the UMAP, colored by putative cell type

# %%
adata.obs['cell_type_putative'] = adata.obs['leiden'].map(cluster_mapping_dictionary)
scanpy.pl.umap(adata, color='cell_type_putative')

# %% [markdown]
# You can imagine that for your own data you would want to iterate on clustering, labeling, and identifying marker genes until you are happy with your clusters

# %% [markdown]
# Let's take a rough look at differentially expressed genes among these groups

# %%
scanpy.tl.rank_genes_groups(adata, 'cell_type', method='wilcoxon')
scanpy.pl.rank_genes_groups(adata)

# %% [markdown]
# Let's make volcano plot

# %%
result=scanpy.get.rank_genes_groups_df(adata, group=['neurons', 'astrocytes'], pval_cutoff=(0.01))
result.head()
# Out:
#      group    names     scores  logfoldchanges         pvals     pvals_adj
# 0  neurons     MEG3  14.894347        7.395569  3.586723e-50  6.897628e-46
# 1  neurons   GABRG2  14.492606        6.931857  1.349250e-47  9.629404e-44
# 2  neurons   SNAP25  14.464840        6.363084  2.020746e-47  9.629404e-44
# 3  neurons  TMEM130  14.461370        6.710864  2.125277e-47  9.629404e-44
# 4  neurons   GABRB2  14.450089        7.585397  2.503615e-47  9.629404e-44

# %%
result["-logP"] = -np.log(result["pvals_adj"].astype("float"))
result.head()
# Out:
#      group    names     scores  logfoldchanges         pvals     pvals_adj  \
# 0  neurons     MEG3  14.894347        7.395569  3.586723e-50  6.897628e-46
# 1  neurons   GABRG2  14.492606        6.931857  1.349250e-47  9.629404e-44
# 2  neurons   SNAP25  14.464840        6.363084  2.020746e-47  9.629404e-44
# 3  neurons  TMEM130  14.461370        6.710864  2.125277e-47  9.629404e-44
# 4  neurons   GABRB2  14.450089        7.585397  2.503615e-47  9.629404e-44
#
#         -logP
# 0  103.987737
# 1   99.048923
# 2   99.048923
# 3   99.048923
# 4   99.048923

# %%
fh, ax = plt.subplots(1, 1, figsize=(4, 4))
ax.scatter(x=result['logfoldchanges'],
           y=result['-logP'],
           marker =',')
ax.set_xlabel('-log2(FC)')
ax.set_ylabel('-log10(p)')
# Out:
# Text(0, 0.5, '-log10(p)')

# %% [markdown]
# # BONUS: time series analysis

# %% [markdown]
# ## 3) Time series data -  Examining extracellular spiking data

# %% [markdown]
# ### Detect spike times
# Let's say we want to detect the times when the neuron fired an action potential (spike).
#
# Steps:
# 1. Filter the signal: remove low-frequency changes in baseline using a **high-pass filter**
# 2. Find the points where the trace goes beyond some threshold value
# 3. Make sure you aren't double counting spikes!

# %% [markdown]
# ## 4) Spike triggered average of a neuron
#
# Reliable spike detection is beyond the scope of this class, so we're going to skip some intervening steps and start with already detected spikes.
# A common way to represent spike times is a vector that is zero everywhere except the time points where the spike occurred.
#
# Let's load some processed spike time data, alongside the visual stimulus that was shown to the neuron. These data are from a neuron in blowfly called H1 that is sensitive to motion in the visual world. The stimulus is reported as the rotational velocity (in degrees/second). Both the stimulus and spike times have a sampling period of 2 msec.

# %% [markdown]
# `'stim'` is the stimulus
#
# `'rho'` is the spike binary vector
#
# Let's make some variables to be able to refer to each of these a bit more easily. We'll also make a vector of timestamps based on the knowledge that each time step is 2 msec

# %% [markdown]
# Now let's jsut plot a bit of the stim and response trace to see what we're looking at

# %% [markdown]
# We're going to figure out what makes this neuron spike. To do that we will compute the **spike triggered average stimulus** this, as the name implies is the average stimulus that triggers a spike. The strategy is straightforward:
# 1. Define some window of time to look backwards (let's say 300 datapoints, or 600 msec)
# 2. Find all the spike times
# 3. Pull out the stimulus for the 300 datapoints preceding each spike
# 4. Average all the stimuli together

# %% [markdown]
# Now let's plot our spike triggered average. To visualize it, we need a time vector for the x axis...
